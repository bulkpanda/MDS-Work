# %%
import os
import json
import requests
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# %%
folderPath = '2025'

# %%
def load_credentials():
    load_dotenv()
    email = os.getenv("DASH_EMAIL")
    password = os.getenv("DASH_PASSWORD")
    if not email or not password:
        raise ValueError("EMAIL and PASSWORD must be set in the .env file")
    return email, password

def get_csrf_token(session, login_url):
    response = session.get(login_url)
    soup = BeautifulSoup(response.text, "html.parser")
    token = soup.find("input", {"name": "csrfmiddlewaretoken"})
    if not token:
        raise RuntimeError("CSRF token not found in login page.")
    return token["value"]

def login(session, login_url, email, password, csrf_token):
    login_data = {
        "email": email,
        "password": password,
        "csrfmiddlewaretoken": csrf_token
    }
    headers = {"Referer": login_url}
    response = session.post(login_url, data=login_data, headers=headers)
    return response

def fetch_api_data(session, api_url):

    response = session.get(api_url)
    content_type = response.headers.get("Content-Type", "")
    
    if "application/json" not in content_type:
        raise ValueError("API response is not JSON:\n" + response.text[:300])
    
    data = response.json()
    if not data.get("success", False):
        raise RuntimeError("API returned failure: " + data.get("message", "No message"))
    
    if "result" not in data:
        raise KeyError("'result' key not found in API response.")
    
    return data["result"]

def jsonToExcel(data, supervisorMainFields, studentMainFields, outputFile):
    flattenedEntries = []
    nestedEntries = []
    for entry in data:
        date = entry.get("date")
        
        # Base fields
        baseData = {k: v for k, v in entry.items() if not isinstance(v, dict)}
        
        # Supervisor fields
        supervisorData = entry.get('supervisor_data', {})
        supervisorFieldsExtracted = {k: supervisorData.get(k) for k in supervisorMainFields}
        supervisorRemainingData = {k: v for k, v in supervisorData.items() if k not in supervisorMainFields}
        
        # Student fields
        studentData = entry.get('student_data', {})
        studentFieldsExtracted = {k: studentData.get(k) for k in studentMainFields}
        studentRemainingData = {k: v for k, v in studentData.items() if k not in studentMainFields}
        
        # Fully flattened (all keys)
        flattenedEntry = {**baseData, **studentData, **supervisorData}
        flattenedEntries.append(flattenedEntry)

        # Nested version
        nestedEntry = {
            **baseData,
            **supervisorFieldsExtracted,
            **studentFieldsExtracted,
            'student_data': json.dumps(studentRemainingData, indent=2, ensure_ascii=False),
            'supervisor_data': json.dumps(supervisorRemainingData, indent=2, ensure_ascii=False)
        }
        nestedEntries.append(nestedEntry)

    with pd.ExcelWriter(outputFile, engine='openpyxl') as writer:
        # Save flattened all_data
        df_all_flat = pd.DataFrame(flattenedEntries)
        df_all_flat.to_excel(writer, sheet_name='all_data_flat', index=False)

        # Save nested all_data
        df_all_nested = pd.DataFrame(nestedEntries)
        df_all_nested.to_excel(writer, sheet_name='all_data_nested', index=False)

def getandprintData(session, api_url):
    try:
        print(f"🔄 Fetching API data for {api_url}...")
        result_data = fetch_api_data(session, api_url)
        print("✅ API data retrieved successfully.")
        json_preview = json.dumps(result_data, indent=2)
        print("Preview of result (first 1500 characters):")
        print(json_preview[:1500] + "..." if len(json_preview) > 1500 else json_preview)
        return result_data
    except Exception as e:
        print(f"❌ Error fetching API data: {e}")
        return []

# %%
def fetchAllPages(session, baseUrl, limit=1000):
    allData = []
    offset = 0

    while True:
        url = f"{baseUrl}?limit={limit}&offset={offset}"
        print(f"Fetching: {url}")

        results = getandprintData(session, url)

        if not results:
            break  # no more pages

        allData.extend(results)
        offset += limit

    return allData

def main():
    loginUrl = "https://www.unimelb-dash.com/accounts/login/"
    apiBaseUrl = "https://www.unimelb-dash.com/assessment/caf/v2/get"

    session = requests.Session()

    try:
        email, password = load_credentials()
        csrfToken = get_csrf_token(session, loginUrl)
        loginResp = login(session, loginUrl, email, password, csrfToken)

        if "Please sign in" in loginResp.text:
            print("❌ Login failed: invalid credentials or CSRF mismatch.")
            return

        print("✅ Login successful!")

        allForms = fetchAllPages(session, apiBaseUrl)
        # save to json file
        with open(f"{folderPath}/allData.json", "w", encoding="utf-8") as f:
            json.dump(allForms, f, ensure_ascii=False, indent=2)
        print(f"Total forms fetched: {len(allForms)}")
        # Now you can process allForms or convert to df

    except Exception as e:
        print(f"❌ Error: {e}")
        return

if __name__ == "__main__":
    main()
# Out:
# ✅ Login successful!
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=0
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=0...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 16,
#     "student_name": "Test Student",
#     "student_number": 1234567,
#     "datetime": "2025-07-08T00:00:00",
#     "cohort": "BOH2",
#     "subject": "ORAL20003",
#     "type": "Simulation",
#     "forms": {},
#     "completed": false
#   },
#   {
#     "assessment_id": 17,
#     "student_name": "Roya Akbari",
#     "student_number": 1529551,
#     "datetime": "2025-07-07T00:00:00",
#     "cohort": "DDS2",
#     "subject": "DENT90146",
#     "type": "Clinic",
#     "forms": {
#       "K2AVv1": {
#         "data": {
#           "student": {
#             "072": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes"
#             },
#             "721-PI": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes"
#             },
#             "722-PI": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes"
#             },
#             "reflection": "For impressions trays were too narrow (thus need for custom tray), maxillary impression took 2 tries (pt has a deep palate), for mandibular impression 37B missing but won't affect tx plan "
#           },
#           "assessor": {}
#         },
#         "role": "Operator",
#         "clinic": "Rem Pros",
#         "scales": {
#           "time_mgmt": {
#             "name": "Time Manageme...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=1000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=1000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 1113,
#     "student_name": "Jackie Tran",
#     "student_number": 1475117,
#     "datetime": "2025-07-21T00:00:00",
#     "cohort": "BOH1",
#     "subject": "ORAL10005",
#     "type": "Clinic",
#     "forms": {
#       "M96Ham": {
#         "data": {
#           "student": {
#             "011": {
#               "MC1": "Not Assessed",
#               "MC2": "Not Assessed",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Not Assessed",
#               "MC7": "Not Assessed",
#               "MC8": "Not Assessed",
#               "MC9": "Not Assessed",
#               "MC10": "Not Assessed",
#               "MC11": "Not Assessed",
#               "MC12": "Not Assessed",
#               "MC13": "Not Assessed",
#               "MC14": "Not Assessed",
#               "MC15": "Not Assessed",
#               "MC16": "Not Assessed",
#               "MC17": "Not Assessed"
#             },
#             "reflection": "Today we did an extra oral exam and there was no prominent findings on the patient. I didn't remember the names of a few of the glands. We were taught the different palpation techniques and their uses. When checking for MOM I missed the temporalis which was corrected. I also put my fingers on the wrong area when first checking for the TMJ which was also corrected. I placed my hands too close to the cheeks rather than the ear area.",
#             "OHP1-PL-011-EO": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3"...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=2000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=2000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 2186,
#     "student_name": "Asel Kondi",
#     "student_number": 1525830,
#     "datetime": "2025-07-28T00:00:00",
#     "cohort": "DDS2",
#     "subject": "DENT90146",
#     "type": "Simulation",
#     "forms": {
#       "EzLy8Z": {
#         "data": {
#           "student": {
#             "532": {
#               "MC1": "Yes",
#               "MC2": "Not Assessed",
#               "MC3": "Not Assessed",
#               "MC4": "Not Assessed",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "No",
#               "MC9": "Yes",
#               "MC10": "No",
#               "MC11": "Yes",
#               "MC12": "Yes",
#               "MC13": "Not Assessed",
#               "MC14": "Yes",
#               "MC15": "Yes",
#               "MC16": "Yes",
#               "MC17": "Yes"
#             },
#             "reflection": "had hard time getting tofflemire into contact bw 55 and 16, even after trying to insert a wooden wedge in. Would ideally opt for V3 matrix system. Overall felt cavity prep went well, would like to work more on resto as found it hard to adapt material into the small cavity space, especially since hand instruments were quite large, making it hard to pack into the cavity."
#           },
#           "assessor": {
#             "532": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Not Assessed",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=3000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=3000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 3231,
#     "student_name": "Anna Nguyen",
#     "student_number": 1080733,
#     "datetime": "2025-08-05T00:00:00",
#     "cohort": "DDS2",
#     "subject": "DENT90146",
#     "type": "Clinic",
#     "forms": {
#       "Byf0Q2": {
#         "data": {
#           "student": {
#             "165": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes"
#             },
#             "222": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes"
#             },
#             "114-115": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes"
#             },
#             "LA-2025": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes",
#               "MC11": "Yes",
#               "MC12": "Yes",
#               "MC13": "No"
#             },
#             "reflection": "Need to remember to provide pre-op and post-op instructions for LA - prescribing mild analgesics, avoiding biting, eating hot food/drinks.\nRemember to chart tooth mousse 927O? Instructions - Apply pea-sized amount to internal and external surfaces of te...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=4000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=4000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 4293,
#     "student_name": "Sheng Weng Selwyn Lo",
#     "student_number": 1432714,
#     "datetime": "2025-08-19T00:00:00",
#     "cohort": "DDS2",
#     "subject": "DENT90148",
#     "type": "Simulation",
#     "forms": {
#       "HBinmR": {
#         "data": {
#           "student": {
#             "615": {
#               "MC1": "Yes",
#               "MC2": "No",
#               "MC3": "No",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "No",
#               "MC9": "Yes",
#               "MC10": "Yes",
#               "MC11": "Yes",
#               "MC12": "Yes"
#             },
#             "631": {
#               "MC1": "Not Assessed",
#               "MC2": "Not Assessed",
#               "MC3": "Not Assessed",
#               "MC4": "Not Assessed",
#               "MC5": "Not Assessed",
#               "MC6": "Not Assessed",
#               "MC7": "Not Assessed",
#               "MC8": "Not Assessed"
#             },
#             "reflection": "Assessment: \nOver-reduction on the occlusal surface (b/w 2-3mm). Adequate reduction on buccal, lingual reduction margin a little over prepped (>0.5mm). Mesial and Distal reduction adequate. No undercuts, and reduced with adequate taper. But not a smooth preparation: line angles still present on lingual surfaces (not sure how to remove them with Arkansas white stone). Lingual margin outline also have sharp angle, did not identify without demonstrator's help\n\nReflectio...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=5000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=5000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 5341,
#     "student_name": "Brendan Pugh",
#     "student_number": 1648225,
#     "datetime": "2025-08-29T00:00:00",
#     "cohort": "DDS1",
#     "subject": "DENT90141",
#     "type": "Simulation",
#     "forms": {
#       "ZzuhCv": {
#         "data": {
#           "student": {
#             "DDS1-DDI": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes"
#             },
#             "DDS1-PAP": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes",
#               "MC11": "Yes",
#               "MC12": "Yes",
#               "MC13": "Yes"
#             },
#             "DDS1-TMP": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes"
#             },
#             "DDS1-PDPC": {
#               "MC1": "Not Assessed",
#               "MC2": "Not Assessed",
#               "MC3": "Not Assessed",
#               "MC4": "Not Assessed",
#               "MC5": "Not Assessed"
#             },
#             "DDS1-POAR": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "No",
#               "MC4": "...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=6000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=6000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 6380,
#     "student_name": "Yejin Kim",
#     "student_number": 1613317,
#     "datetime": "2025-09-10T00:00:00",
#     "cohort": "BOH1",
#     "subject": "ORAL10005",
#     "type": "Simulation",
#     "forms": {
#       "7jYjVV": {
#         "data": {
#           "student": {
#             "221": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes"
#             },
#             "222": {
#               "MC1": "No",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes",
#               "MC11": "Yes",
#               "MC12": "Yes",
#               "MC13": "Yes",
#               "MC14": "No"
#             },
#             "11-12": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes"
#             },
#             "114-hs": {
#               "MC1": "Yes",
#               "MC2": "Not Assessed",
#               "MC3": "Yes",
#               "MC4": "No",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#        ...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=7000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=7000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 7445,
#     "student_name": "Kirandeep Toor",
#     "student_number": 1396029,
#     "datetime": "2025-09-19T00:00:00",
#     "cohort": "DDS1",
#     "subject": "DENT90141",
#     "type": "Simulation",
#     "forms": {
#       "asfBGl": {
#         "data": {
#           "student": {
#             "DDS1-DDI": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes"
#             },
#             "DDS1-SMP": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes"
#             },
#             "DDS1-PORR": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "No",
#               "MC8": "Yes"
#             },
#             "reflection": "I did struggle with recreating the tooth anatomy, specifically the marginal ridge without making it look too boxy. Overall, I did think the session went well and I was able to understand how to properly place a sectional matrix by trying out different wedge sizes."
#           },
#           "assessor": {
#             "DDS1-DDI": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#     ...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=8000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=8000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 8513,
#     "student_name": "Laura Yeo",
#     "student_number": 1172673,
#     "datetime": "2025-10-02T00:00:00",
#     "cohort": "DDS2",
#     "subject": "DENT90146",
#     "type": "Clinic",
#     "forms": {
#       "1DEbUB": {
#         "data": {
#           "student": {
#             "522": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "No",
#               "MC10": "Yes",
#               "MC11": "Yes"
#             },
#             "reflection": "Good LA, good dental dam, caries removal was good but learned a new tip to look for 'dust' when removing caries with a slow speed as this will no longer form when carious dentine has been removed, good RC placement except for small gingival overhang - had to remove with a needle bur slightly below the gingiva - be more confident. Good time management."
#           },
#           "assessor": {
#             "522": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes",
#               "MC11": "Yes"
#             },
#             "Consent": {
#               "MC1": "Yes"
#             },
#             "time_mgmt": {
#               "s...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=9000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=9000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# [
#   {
#     "assessment_id": 9582,
#     "student_name": "Amal Barakat",
#     "student_number": 1775573,
#     "datetime": "2025-10-15T00:00:00",
#     "cohort": "BOH1",
#     "subject": "ORAL10005",
#     "type": "Simulation",
#     "forms": {
#       "8A2Ykz": {
#         "data": {
#           "student": {
#             "114-hs": {
#               "MC1": "Yes",
#               "MC2": "Yes",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "Yes",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes"
#             },
#             "reflection": "i feel like after laura taught me about the angulation and i applied it with her before doing the milestone, i understood how to do it more, as im a visual learner. i need to stay adjusting well, and make it so the too is at an angle with the tooth. "
#           },
#           "assessor": {
#             "114-hs": {
#               "MC1": "Yes",
#               "MC2": "Not Assessed",
#               "MC3": "Yes",
#               "MC4": "Yes",
#               "MC5": "No",
#               "MC6": "Yes",
#               "MC7": "Yes",
#               "MC8": "Yes",
#               "MC9": "Yes",
#               "MC10": "Yes"
#             },
#             "time_mgmt": {
#               "scale": "4"
#             },
#             "reflection": "Good angulation, well done. Just make sure to practice rolling to have continuous strokes. ",
#             "entrustment": {
#               "scale": "3"
#    ...
# Fetching: https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=10000
# 🔄 Fetching API data for https://www.unimelb-dash.com/assessment/caf/v2/get?limit=1000&offset=10000...
# ✅ API data retrieved successfully.
# Preview of result (first 1500 characters):
# []
# Total forms fetched: 9641

# %%
def main():
    login_url = "https://www.unimelb-dash.com/accounts/login/"
    api_url_1 = "https://www.unimelb-dash.com/assessment/caf/v1/get/"
    api_url_2 = "https://www.unimelb-dash.com/assessment/mini-cex/get/"
    api_url_3 = "https://www.unimelb-dash.com/assessment/osce/get/"

    # fields to pull out of supervis
    supervisorMainFields = ['time_mgmt', 'entrustment', 'communication', 'professionalism', 'assessor_feedback', 
                        'clinical_incident', 'patient_complexity']
    studentMainFields = ['student_feedback']
    session = requests.Session()
    try:
        email, password = load_credentials()
        csrf_token = get_csrf_token(session, login_url)
        login_response = login(session, login_url, email, password, csrf_token)

        if "Please sign in" in login_response.text:
            print("❌ Login failed: invalid credentials or CSRF mismatch.")
            return

        print("✅ Login successful!")

        result_data_1 = getandprintData(session, api_url_1)
        result_data_2 = getandprintData(session, api_url_2) # mini-cex
        result_data_3 = getandprintData(session, api_url_3) # osce
        
    except Exception as e:
        print(f"❌ Error: {e}")
        return

    outputFile = "2025/_unimelb_dash_all_data.xlsx"
    jsonToExcel(result_data_1, supervisorMainFields, studentMainFields, outputFile)
    print(f"✅ Data saved to {outputFile} successfully.")

if __name__ == "__main__":
    main()
